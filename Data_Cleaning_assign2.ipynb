# %%
import pandas as pd
import numpy as np

# %%
url='https://raw.githubusercontent.com/LearnDataSci/article-resources/master/Python%20Pandas%20Tutorial%20A%20Complete%20Introduction%20for%20Beginners/IMDB-Movie-Data.csv'
df=pd.read_csv(url,error_bad_lines=False,index_col=0)
df
# Out:
#                         Title                     Genre  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
# ...                       ...                       ...
# 996      Secret in Their Eyes       Crime,Drama,Mystery
# 997           Hostel: Part II                    Horror
# 998    Step Up 2: The Streets       Drama,Music,Romance
# 999              Search Party          Adventure,Comedy
# 1000               Nine Lives     Comedy,Family,Fantasy
#
#                                             Description              Director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               1000 non-null   object
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 93.8+ KB

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                         Title                     Genre  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
# ...                       ...                       ...
# 996      Secret in Their Eyes       Crime,Drama,Mystery
# 997           Hostel: Part II                    Horror
# 998    Step Up 2: The Streets       Drama,Music,Romance
# 999              Search Party          Adventure,Comedy
# 1000               Nine Lives     Comedy,Family,Fantasy
#
#                                             Description              Director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df.columns=[col.upper() for col in df]
df.columns
# Out:
# Index(['TITLE', 'GENRE', 'DESCRIPTION', 'DIRECTOR', 'ACTORS', 'YEAR',
#        'RUNTIME (MINUTES)', 'RATING', 'VOTES', 'REVENUE (MILLIONS)',
#        'METASCORE'],
#       dtype='object')

# %%
df.isnull()
# Out:
#       TITLE  GENRE  DESCRIPTION  DIRECTOR  ACTORS   YEAR  RUNTIME (MINUTES)  \
# Rank
# 1     False  False        False     False   False  False              False
# 2     False  False        False     False   False  False              False
# 3     False  False        False     False   False  False              False
# 4     False  False        False     False   False  False              False
# 5     False  False        False     False   False  False              False
# ...     ...    ...          ...       ...     ...    ...                ...
# 996   False  False        False     False   False  False              False
# 997   False  False        False     False   False  False              False
# 998   False  False        False     False   False  False              False
# 999   False  False        False     False   False  False              False
# 1000  False  False        False     False   False  False              False
#
# ...

# %%
df.isnull().sum()
# Out:
# TITLE                   0
# GENRE                   0
# DESCRIPTION             0
# DIRECTOR                0
# ACTORS                  0
# YEAR                    0
# RUNTIME (MINUTES)       0
# RATING                  0
# VOTES                   0
# REVENUE (MILLIONS)    128
# METASCORE              64
# dtype: int64

# %%
df.dropna()
# Out:
#                          TITLE                     GENRE  \
# Rank
# 1      Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                   Prometheus  Adventure,Mystery,Sci-Fi
# 3                        Split           Horror,Thriller
# 4                         Sing   Animation,Comedy,Family
# 5                Suicide Squad  Action,Adventure,Fantasy
# ...                        ...                       ...
# 994   Resident Evil: Afterlife   Action,Adventure,Horror
# 995                  Project X                    Comedy
# 997            Hostel: Part II                    Horror
# 998     Step Up 2: The Streets       Drama,Music,Romance
# 1000                Nine Lives     Comedy,Family,Fantasy
#
#                                             DESCRIPTION              DIRECTOR  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
df.dropna(axis=1)
# Out:
#                         TITLE                     GENRE  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
# ...                       ...                       ...
# 996      Secret in Their Eyes       Crime,Drama,Mystery
# 997           Hostel: Part II                    Horror
# 998    Step Up 2: The Streets       Drama,Music,Romance
# 999              Search Party          Adventure,Comedy
# 1000               Nine Lives     Comedy,Family,Fantasy
#
#                                             DESCRIPTION              DIRECTOR  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
ra=df['RATING']
ra
# Out:
# Rank
# 1       8.1
# 2       7.0
# 3       7.3
# 4       7.2
# 5       6.2
#        ...
# 996     6.2
# 997     5.5
# 998     6.2
# 999     5.6
# 1000    5.3
# Name: RATING, Length: 1000, dtype: float64

# %%
ra_mean= ra.mean()
ra_mean
# Out:
# 6.723200000000003

# %%
ra.fillna(ra_mean)
# Out:
# Rank
# 1       8.1
# 2       7.0
# 3       7.3
# 4       7.2
# 5       6.2
#        ...
# 996     6.2
# 997     5.5
# 998     6.2
# 999     5.6
# 1000    5.3
# Name: RATING, Length: 1000, dtype: float64

# %%
ra.fillna(ra_mean,inplace=True)

# %%
df.isnull().sum()
# Out:
# TITLE                   0
# GENRE                   0
# DESCRIPTION             0
# DIRECTOR                0
# ACTORS                  0
# YEAR                    0
# RUNTIME (MINUTES)       0
# RATING                  0
# VOTES                   0
# REVENUE (MILLIONS)    128
# METASCORE              64
# dtype: int64

# %%
df
# Out:
#                         TITLE                     GENRE  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
# ...                       ...                       ...
# 996      Secret in Their Eyes       Crime,Drama,Mystery
# 997           Hostel: Part II                    Horror
# 998    Step Up 2: The Streets       Drama,Music,Romance
# 999              Search Party          Adventure,Comedy
# 1000               Nine Lives     Comedy,Family,Fantasy
#
#                                             DESCRIPTION              DIRECTOR  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
df.drop(['VOTES','METASCORE'], inplace=True,axis=1)

# %%
df.columns
# Out:
# Index(['TITLE', 'GENRE', 'DESCRIPTION', 'DIRECTOR', 'ACTORS', 'YEAR',
#        'RUNTIME (MINUTES)', 'RATING', 'REVENUE (MILLIONS)'],
#       dtype='object')

# %%
df.rename(columns={
    'REVENUE (MILLIONS)':'REVENUE',
    'RUNTIME (MINUTES)': 'RUNTIME'
} ,inplace= True)

df.columns
# Out:
# Index(['TITLE', 'GENRE', 'DESCRIPTION', 'DIRECTOR', 'ACTORS', 'YEAR',
#        'RUNTIME', 'RATING', 'REVENUE'],
#       dtype='object')

# %%
df.loc[100]
# Out:
# TITLE                                               The Departed
# GENRE                                       Crime,Drama,Thriller
# DESCRIPTION    An undercover cop and a mole in the police att...
# DIRECTOR                                         Martin Scorsese
# ACTORS         Leonardo DiCaprio, Matt Damon, Jack Nicholson,...
# YEAR                                                        2006
# RUNTIME                                                      151
# RATING                                                       8.5
# REVENUE                                                   132.37
# Name: 100, dtype: object

# %%
df.describe()
# Out:
#               YEAR      RUNTIME       RATING     REVENUE
# count  1000.000000  1000.000000  1000.000000  872.000000
# mean   2012.783000   113.172000     6.723200   82.956376
# std       3.205962    18.810908     0.945429  103.253540
# min    2006.000000    66.000000     1.900000    0.000000
# 25%    2010.000000   100.000000     6.200000   13.270000
# 50%    2014.000000   111.000000     6.800000   47.985000
# 75%    2016.000000   123.000000     7.400000  113.715000
# max    2016.000000   191.000000     9.000000  936.630000
